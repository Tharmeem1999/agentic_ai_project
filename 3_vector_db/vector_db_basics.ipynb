# %%
import chromadb

client = chromadb.Client()

# %%
collection = client.create_collection("news_articles")

# %%
collection.add(
    ids=["id1", "id2", "id3", "id4"],
    documents=[
        "Apple is leading in a smart phone game with iPhone sales up by 35%",
        "Tesla booked a minor profit of 1 billion $ in Q2",
        "Apples are high in fiber, vitamin C, and various antioxidants",
        "SpaceX got NASA contract worth 10 billion $",
    ]
)
# Out:
# /home/asus/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|█████████████████████████████████████████████████████████████████████████| 79.3M/79.3M [04:06<00:00, 337kiB/s]

# %%
# Fetch documents + embeddings
data = collection.get(
    include=["documents", "embeddings", "metadatas"]
)

# Print embeddings
for i, emb in enumerate(data["embeddings"]):
    print(f"\nDocument {i+1}")
    print("Text:", data["documents"][i])
    print("Embedding length:", len(emb))
    print("First 10 values:", emb[:10])
# Out:
# Document 1
# Text: Apple is leading in a smart phone game with iPhone sales up by 35%
# Embedding length: 384
# First 10 values: [ 0.03640455  0.01021047  0.08642428 -0.12735228 -0.01895927  0.00309626
#   0.01671757  0.05566161  0.02376827  0.11325452]
#
# Document 2
# Text: Tesla booked a minor profit of 1 billion $ in Q2
# Embedding length: 384
# First 10 values: [ 0.03228296  0.08888533  0.02695832  0.07444265 -0.06773707 -0.03529561
#  -0.02407438  0.10166305  0.02283024  0.02386423]
#
# Document 3
# Text: Apples are high in fiber, vitamin C, and various antioxidants
# Embedding length: 384
# First 10 values: [ 0.0451243  -0.03145008  0.01100093  0.08058897  0.00119946  0.02187006
#  -0.00926968 -0.013256    0.00425177  0.02350495]
#
# Document 4
# Text: SpaceX got NASA contract worth 10 billion $
# Embedding length: 384
# First 10 values: [-0.02309863  0.03526219  0.06101782 -0.02734394 -0.08042093 -0.02970156
#   0.07421495  0.05592686  0.02907892  0.07048377]

# %%
results = collection.query(
    query_texts = ["This is a query related to Elon Musk"],
    n_results = 2
)

print(results)
# Out:
# {'ids': [['id2', 'id4']], 'embeddings': None, 'documents': [['Tesla booked a minor profit of 1 billion $ in Q2', 'SpaceX got NASA contract worth 10 billion $']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None]], 'distances': [[1.5166925191879272, 1.5598335266113281]]}

# %%
results = collection.query(
    query_texts = ["I love Tim Cook"],
    n_results = 2
)

print(results)
# Out:
# {'ids': [['id1', 'id2']], 'embeddings': None, 'documents': [['Apple is leading in a smart phone game with iPhone sales up by 35%', 'Tesla booked a minor profit of 1 billion $ in Q2']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None]], 'distances': [[1.8999354839324951, 1.957904577255249]]}

# %%
results = collection.query(
    query_texts = ["Tips for improve health"],
    n_results = 4
)

print(results)
# Out:
# {'ids': [['id3', 'id1', 'id2', 'id4']], 'embeddings': None, 'documents': [['Apples are high in fiber, vitamin C, and various antioxidants', 'Apple is leading in a smart phone game with iPhone sales up by 35%', 'Tesla booked a minor profit of 1 billion $ in Q2', 'SpaceX got NASA contract worth 10 billion $']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None, None, None]], 'distances': [[1.502951979637146, 1.9070281982421875, 2.07548451423645, 2.1685075759887695]]}
