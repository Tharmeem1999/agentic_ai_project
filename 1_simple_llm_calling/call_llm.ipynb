# %%
from dotenv import load_dotenv
from langchain_groq import ChatGroq

load_dotenv()
# Out:
# True

# %%
llm = ChatGroq(model = "llama-3.3-70b-versatile")

response = llm. invoke("How many moons Jupiter have?")
print(response)
# Out:
# content="Jupiter has a total of 92 confirmed moons. However, it's worth noting that this number may not be definitive, as there are many smaller, irregular moons that have not been officially confirmed or named. The four largest and most well-known moons of Jupiter are Io, Europa, Ganymede, and Callisto, which are known as the Galilean moons because they were discovered by Galileo Galilei in 1610." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 90, 'prompt_tokens': 41, 'total_tokens': 131, 'completion_time': 0.186719646, 'completion_tokens_details': None, 'prompt_time': 0.002488681, 'prompt_tokens_details': None, 'queue_time': 0.050336499, 'total_time': 0.189208327}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019fb093-2524-75a1-9798-e96b3bc3b5a6-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tok
# ...
